# %%
import pandas as pd
import numpy as np
import os

# %%
df_ords=pd.read_csv(r'd:/Instacart Basket Analysis_2024-01-02/02 Data/Prepared Data/orders_wrangled.csv', index_col=False)

# %%
df_prods=pd.read_csv(r'd:\Instacart Basket Analysis_2024-01-02\02 Data\Original data\products.csv', index_col=False)

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06       3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01       2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01       2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00       1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01       3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02       6.000000e+00
#
#        order_hour_of_day  days_since_previous_order
# count       3.421083e+06               3.214874e+06
# mean        1.345202e+01               1.111484e+01
# std         4.226088e+00               9.206737e+00
# min         0.000000e+00               0.000000e+00
# 25%         1.000000e+01               4.000000e+00
# ...

# %%
df_ords.shape
# Out:
# (3421083, 6)

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
#mixed data type - test

# %%
df_test = pd.DataFrame()

# %%
df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
#checking whether a dataframe contains any mixed-type

# %%
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix
# C:\Users\jinu5\AppData\Local\Temp\ipykernel_17460\1786467950.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)

# %%
df_test[[col]].applymap(type)
# Out:
# C:\Users\jinu5\AppData\Local\Temp\ipykernel_11372\2448242965.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_test[[col]].applymap(type)
#               mix
# 0   <class 'str'>
# 1   <class 'str'>
# 2   <class 'int'>
# 3  <class 'bool'>

# %%
#Finding Missing Values from df_prods

# %%
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
df_prods.isnull()
# Out:
#        product_id  product_name  aisle_id  department_id  prices
# 0           False         False     False          False   False
# 1           False         False     False          False   False
# 2           False         False     False          False   False
# 3           False         False     False          False   False
# 4           False         False     False          False   False
# ...           ...           ...       ...            ...     ...
# 49688       False         False     False          False   False
# 49689       False         False     False          False   False
# 49690       False         False     False          False   False
# 49691       False         False     False          False   False
# 49692       False         False     False          False   False
#
# [49693 rows x 5 columns]

# %%
# create new dataframe containing only missing value

# %%
df_nan=df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
# create a new dataframe only having non-missing values

# %%
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
#checking duplicated values

# %%
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
print(df_prods_clean[df_prods_clean['product_id'] ==462])
# Out:
#      product_id                       product_name  aisle_id  department_id  \
# 461         462  Fiber 4g Gummy Dietary Supplement        70             11
# 462         462  Fiber 4g Gummy Dietary Supplement        70             11
#
#      prices
# 461     4.8
# 462     4.8

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
# create a new dataframe that doesn’t include the duplicates

# %%
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
df_prods_clean_no_dups1 = df_prods_clean_no_dups[df_prods_clean_no_dups.duplicated()]

# %%
df_prods_clean_no_dups1
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id, prices]
# Index: []

# %%
# export datafame

# %%
df_prods_clean_no_dups.to_csv('e:/Instacart Basket Analysis_2024-01-02/02 Data/Prepared Data/products_checked.csv')

# %% [markdown]
# # task 4-5

# %%
# Step2. Run the df.describe() function on your df_ords dataframe

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06       3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01       2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01       2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00       1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01       3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02       6.000000e+00
#
#        order_hour_of_day  days_since_previous_order
# count       3.421083e+06               3.214874e+06
# mean        1.345202e+01               1.111484e+01
# std         4.226088e+00               9.206737e+00
# min         0.000000e+00               0.000000e+00
# 25%         1.000000e+01               4.000000e+00
# ...

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df_ords.describe()
# Out:
#         order_id    user_id  order_number  order_day_of_week  \
# count 3421083.00 3421083.00    3421083.00         3421083.00
# mean  1710542.00  102978.21         17.15               2.78
# std    987581.74   59533.72         17.73               2.05
# min         1.00       1.00          1.00               0.00
# 25%    855271.50   51394.00          5.00               1.00
# 50%   1710542.00  102689.00         11.00               3.00
# 75%   2565812.50  154385.00         23.00               5.00
# max   3421083.00  206209.00        100.00               6.00
#
#        order_hour_of_day  days_since_previous_order
# count         3421083.00                 3214874.00
# mean               13.45                      11.11
# std                 4.23                       9.21
# min                 0.00                       0.00
# 25%                10.00                       4.00
# 50%                13.00                       7.00
# ...

# %%
# In'days_since_previous_order', 
# the total count is less than other columns & min is 0 --> probably #'days_since_previous_order' contains 'NaN' 
# Max is 30 (days) --> this value could be more than 30 (e.g. 43days or etc.)

# %%
# Step 3. Check for mixed-type data in your df_ords dataframe

# %%
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)
# Out:
# C:\Users\jinu5\AppData\Local\Temp\ipykernel_17460\1946670780.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\jinu5\AppData\Local\Temp\ipykernel_17460\1946670780.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\jinu5\AppData\Local\Temp\ipykernel_17460\1946670780.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\jinu5\AppData\Local\Temp\ipykernel_17460\1946670780.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# ...

# %%
# Step 4. - there is no mixed-type data

# %%
# Step 5. Checking missing value in df_ords

# %%
df_ords.isnull().sum()
# Out:
# order_id                          0
# user_id                           0
# order_number                      0
# order_day_of_week                 0
# order_hour_of_day                 0
# days_since_previous_order    206209
# dtype: int64

# %%
df_ords_nan=df_ords[df_ords['days_since_previous_order'].isnull() == True]

# %%
df_ords_nan
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 0         2539329        1             1                  2
# 11        2168274        2             1                  2
# 26        1374495        3             1                  1
# 39        3343014        4             1                  6
# 45        2717275        5             1                  3
# ...           ...      ...           ...                ...
# 3420930    969311   206205             1                  4
# 3420934   3189322   206206             1                  3
# 3421002   2166133   206207             1                  6
# 3421019   2227043   206208             1                  1
# 3421069   3154581   206209             1                  3
#
#          order_hour_of_day  days_since_previous_order
# 0                        8                        NaN
# 11                      11                        NaN
# 26                      14                        NaN
# ...

# %%
# I found 206209 missing value from days_since_previous_order column.
# the missing values have to be kept, becaue this NaN in 'days_since_previous_order' means that they aer new customer
# we can confirm this as new customer by order number 1, as well.

# %%
print(df_ords_nan[df_ords_nan['order_number'] != 1])
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_day_of_week, order_hour_of_day, days_since_previous_order]
# Index: []

# %%
# Step 6. Address the missing values using an appropriate method.

# %%
## days_since_previous_order NaN could be 0, if 0 means new customer. 
## but, '0' means that a customer ordered at the same day.

# %%
print(df_ords[df_ords['days_since_previous_order'] == 0])
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 8         2295261        1             9                  1
# 43        2557754        4             5                  5
# 189       2148135       17            30                  6
# 296        965160       24            19                  0
# 337       3162630       27            24                  2
# ...           ...      ...           ...                ...
# 3420980      4277   206206            47                  2
# 3420985    648225   206206            52                  0
# 3420991   2475308   206206            58                  0
# 3421001   1043943   206206            68                  0
# 3421044   2079142   206208            26                  2
#
#          order_hour_of_day  days_since_previous_order
# 8                       16                       0.00
# 43                      13                       0.00
# 189                     15                       0.00
# ...

# %% [markdown]
# ###  impute NaN to 0

# %%
df_ords['days_since_previous_order'].fillna(0, inplace=True)

# %%
df_ords
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 0         2539329        1             1                  2
# 1         2398795        1             2                  3
# 2          473747        1             3                  3
# 3         2254736        1             4                  4
# 4          431534        1             5                  4
# ...           ...      ...           ...                ...
# 3421078   2266710   206209            10                  5
# 3421079   1854736   206209            11                  4
# 3421080    626363   206209            12                  1
# 3421081   2977660   206209            13                  1
# 3421082    272231   206209            14                  6
#
#          order_hour_of_day  days_since_previous_order
# 0                        8                       0.00
# 1                        7                      15.00
# 2                       12                      21.00
# ...

# %%
# Step 7. a check for duplicate values in your df_ords data

# %%
df_ords_dup=df_ords[df_ords.duplicated()]

# %%
df_ords_dup
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_day_of_week, order_hour_of_day, days_since_previous_order]
# Index: []

# %%
#there is no duplicated values

# %%
#Step 8. Address the duplicates

# %%
#there is no duplicated values

# %%
# Step 9. export cleaned files

# %%
df_prods_clean_no_dups.to_csv('d:/Instacart Basket Analysis_2024-01-02/02 Data/Prepared Data/products_cleaned.csv')

# %%
df_ords.to_csv('d:/Instacart Basket Analysis_2024-01-02/02 Data/Prepared Data/orders_cleaned.csv')

# %%
df_ords
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 0         2539329        1             1                  2
# 1         2398795        1             2                  3
# 2          473747        1             3                  3
# 3         2254736        1             4                  4
# 4          431534        1             5                  4
# ...           ...      ...           ...                ...
# 3421078   2266710   206209            10                  5
# 3421079   1854736   206209            11                  4
# 3421080    626363   206209            12                  1
# 3421081   2977660   206209            13                  1
# 3421082    272231   206209            14                  6
#
#          order_hour_of_day  days_since_previous_order
# 0                        8                       0.00
# 1                        7                      15.00
# 2                       12                      21.00
# ...

# %%
df_prods_clean_no_dups
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19    5.80
# 1           104             13    9.30
# ...
